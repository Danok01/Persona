# %%
import pandas as pd

# %%
df= pd.read_csv('CardioGoodFitness.csv')

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
age = df['Age']

# %%
age.value_counts()
# Out:
# 25    25
# 23    18
# 24    12
# 26    12
# 28     9
# 35     8
# 33     8
# 30     7
# 38     7
# 21     7
# 22     7
# 27     7
# 31     6
# 34     6
# 29     6
# 20     5
# 40     5
# 32     4
# 19     4
# 48     2
# 37     2
# 45     2
# 47     2
# 46     1
# 50     1
# 18     1
# 44     1
# 43     1
# 41     1
# 39     1
# 36     1
# 42     1
# Name: Age, dtype: int64

# %%
sex = df['Gender']

# %%
sex.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
edu = df['Education']

# %%
edu.value_counts()
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %%
relationship = df['MaritalStatus']

# %%
relationship.value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
srtd_miles = df.sort_values(by='Miles', ascending=False)

# %%
srtd_miles[['Miles', 'Fitness']]
# Out:
#      Miles  Fitness
# 173    360        5
# 166    300        5
# 167    280        5
# 170    260        5
# 155    240        5
# ..     ...      ...
# 106     42        2
# 59      38        2
# 51      38        2
# 19      38        2
# 117     21        1
#
# [180 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

miles = df['Miles']
income = df['Income']

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(miles, income, alpha=0.7, label='Data')  # Adjust alpha for transparency

# Calculate and plot the regression line
m, b = np.polyfit(miles, income, 1)  # Linear regression (degree 1)
plt.plot(miles, m * miles + b, color='red', label='Regression Line')

# Add labels and title
plt.xlabel('Miles')
plt.ylabel('Income')
plt.title('Miles vs. Income')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Customers from 150 Miles amd above are considered to be wealthier than others

# %%
# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(df['Age'], df['Miles'], color='skyblue')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Miles Driven')
plt.title('Miles Driven by Age')

# Show the plot
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# This chart shows people in early 30s to early 20s ae more likely to buy expensive products

# %%
# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(df['Product'], df['Income'], color='skyblue')

# Add labels and title
plt.xlabel('Product')
plt.ylabel('Income')
plt.title('Product attracted by income')

# Show the plot
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Calculate the mean income per product
mean_income_per_product = df.groupby('Product')['Income'].mean()

# %%
# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(df['Age'], df['Product'], color='skyblue')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Product')
plt.title('Product attracted by Age')

# Show the plot
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# According to this chart customers in their early 20s to early 30s have show more volatile interest in the product attracted by rich people

# %%
''' This data holds several solutions like comparing the fitness with the age of customers and also identifying the products purchased accordig to Gender. it is not complete dataset, but alot has been learnt from the very few we have managed '''
# Out:
# ' This data holds several solutions like comparing the fitness with the age of customers and also identifying the products purchased accordig to Gender. it is not complete dataset, but alot has been learnt from the very few we have managed '
